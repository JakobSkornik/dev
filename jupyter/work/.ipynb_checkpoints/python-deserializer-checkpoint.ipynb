# %%
from confluent_kafka import Consumer, KafkaException, KafkaError
import avro.schema
import avro.io
import io
import sys

# %%
cfg = {
    "bootstrap.servers": "kafka:9092",
    "group.id": "group-t1",
    "default.topic.config": {"auto.offset.reset": "earliest"}}

# %%
consumer = Consumer(**cfg)
consumer.subscribe(['t1'])

# %%
def load_scheme(scheme_file):
    return avro.schema.Parse(open(scheme_file).read())

# %%
scheme = load_scheme("iris-scheme.avsc")
scheme

# %%
try:
    running = True
    while running:
        msg = consumer.poll(timeout=60000)
        if msg is None:
            continue
        if msg.error():
            if msg.error().code() == KafkaError._PARTITION_EOF:
                sys.stderr.write("Reached end.")
            elif msg.error():
                raise KafkaException(msg.error())
        message = msg.value()
        bytes_reader = io.BytesIO(message)
        deserialzer = avro.io.BinaryDecoder(bytes_reader)
        reader = avro.io.DatumReader(scheme)
        try:
            decoded = reader.read(deserialzer)
            print(decoded)
            sys.stdout.flush()
        except AssertionError:
            continue
except KeyboardInterrupt:
    sys.stderr.write("Keyboard interrupt...")
# Out:
# {'iris_type': '"Setosa"', 'sepal_length': 5.099999904632568, 'sepal_width': 3.5, 'petal_length': 1.399999976158142, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 4.900000095367432, 'sepal_width': 3.0, 'petal_length': 1.399999976158142, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 4.699999809265137, 'sepal_width': 3.200000047683716, 'petal_length': 1.2999999523162842, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 4.599999904632568, 'sepal_width': 3.0999999046325684, 'petal_length': 1.5, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 5.0, 'sepal_width': 3.5999999046325684, 'petal_length': 1.399999976158142, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 5.400000095367432, 'sepal_width': 3.9000000953674316, 'petal_length': 1.7000000476837158, 'petal_width': 0.4000000059604645}
# {'iris_type': '"Setosa"', 'sepal_length': 4.599999904632568, 'sepal_width': 3.4000000953674316, 'petal_length': 1.399999976158142, 'petal_width': 0.30000001192092896}
# {'iris_type': '"Setosa"', 'sepal_length': 5.0, 'sepal_width': 3.4000000953674316, 'petal_length': 1.5, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 4.400000095367432, 'sepal_width': 2.9000000953674316, 'petal_length': 1.399999976158142, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 4.900000095367432, 'sepal_width': 3.0999999046325684, 'petal_length': 1.5, 'petal_width': 0.10000000149011612}
# {'iris_type': '"Setosa"', 'sepal_length': 5.400000095367432, 'sepal_width': 3.700000047683716, 'petal_length': 1.5, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 4.800000190734863, 'sepal_width': 3.4000000953674316, 'petal_length': 1.600000023841858, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 4.800000190734863, 'sepal_width': 3.0, 'petal_length': 1.399999976158142, 'petal_width': 0.10000000149011612}
# {'iris_type': '"Setosa"', 'sepal_length': 4.300000190734863, 'sepal_width': 3.0, 'petal_length': 1.100000023841858, 'petal_width': 0.10000000149011612}
# {'iris_type': '"Setosa"', 'sepal_length': 5.800000190734863, 'sepal_width': 4.0, 'petal_length': 1.2000000476837158, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 5.699999809265137, 'sepal_width': 4.400000095367432, 'petal_length': 1.5, 'petal_width': 0.4000000059604645}
# {'iris_type': '"Setosa"', 'sepal_length': 5.400000095367432, 'sepal_width': 3.9000000953674316, 'petal_length': 1.2999999523162842, 'petal_width': 0.4000000059604645}
# {'iris_type': '"Setosa"', 'sepal_length': 5.099999904632568, 'sepal_width': 3.5, 'petal_length': 1.399999976158142, 'petal_width': 0.30000001192092896}
# {'iris_type': '"Setosa"', 'sepal_length': 5.699999809265137, 'sepal_width': 3.799999952316284, 'petal_length': 1.7000000476837158, 'petal_width': 0.30000001192092896}
# {'iris_type': '"Setosa"', 'sepal_length': 5.099999904632568, 'sepal_width': 3.799999952316284, 'petal_length': 1.5, 'petal_width': 0.30000001192092896}
# {'iris_type': '"Setosa"', 'sepal_length': 5.400000095367432, 'sepal_width': 3.4000000953674316, 'petal_length': 1.7000000476837158, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 5.099999904632568, 'sepal_width': 3.700000047683716, 'petal_length': 1.5, 'petal_width': 0.4000000059604645}
# {'iris_type': '"Setosa"', 'sepal_length': 4.599999904632568, 'sepal_width': 3.5999999046325684, 'petal_length': 1.0, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 5.099999904632568, 'sepal_width': 3.299999952316284, 'petal_length': 1.7000000476837158, 'petal_width': 0.5}
# {'iris_type': '"Setosa"', 'sepal_length': 4.800000190734863, 'sepal_width': 3.4000000953674316, 'petal_length': 1.899999976158142, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 5.0, 'sepal_width': 3.0, 'petal_length': 1.600000023841858, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 5.0, 'sepal_width': 3.4000000953674316, 'petal_length': 1.600000023841858, 'petal_width': 0.4000000059604645}
# {'iris_type': '"Setosa"', 'sepal_length': 5.199999809265137, 'sepal_width': 3.5, 'petal_length': 1.5, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 5.199999809265137, 'sepal_width': 3.4000000953674316, 'petal_length': 1.399999976158142, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 4.699999809265137, 'sepal_width': 3.200000047683716, 'petal_length': 1.600000023841858, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 4.800000190734863, 'sepal_width': 3.0999999046325684, 'petal_length': 1.600000023841858, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 5.400000095367432, 'sepal_width': 3.4000000953674316, 'petal_length': 1.5, 'petal_width': 0.4000000059604645}
# {'iris_type': '"Setosa"', 'sepal_length': 5.199999809265137, 'sepal_width': 4.099999904632568, 'petal_length': 1.5, 'petal_width': 0.10000000149011612}
# {'iris_type': '"Setosa"', 'sepal_length': 5.5, 'sepal_width': 4.199999809265137, 'petal_length': 1.399999976158142, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 4.900000095367432, 'sepal_width': 3.0999999046325684, 'petal_length': 1.5, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 5.0, 'sepal_width': 3.200000047683716, 'petal_length': 1.2000000476837158, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 5.5, 'sepal_width': 3.5, 'petal_length': 1.2999999523162842, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 4.900000095367432, 'sepal_width': 3.5999999046325684, 'petal_length': 1.399999976158142, 'petal_width': 0.10000000149011612}
# {'iris_type': '"Setosa"', 'sepal_length': 4.400000095367432, 'sepal_width': 3.0, 'petal_length': 1.2999999523162842, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 5.099999904632568, 'sepal_width': 3.4000000953674316, 'petal_length': 1.5, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 5.0, 'sepal_width': 3.5, 'petal_length': 1.2999999523162842, 'petal_width': 0.30000001192092896}
# {'iris_type': '"Setosa"', 'sepal_length': 4.5, 'sepal_width': 2.299999952316284, 'petal_length': 1.2999999523162842, 'petal_width': 0.30000001192092896}
# {'iris_type': '"Setosa"', 'sepal_length': 4.400000095367432, 'sepal_width': 3.200000047683716, 'petal_length': 1.2999999523162842, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 5.0, 'sepal_width': 3.5, 'petal_length': 1.600000023841858, 'petal_width': 0.6000000238418579}
# {'iris_type': '"Setosa"', 'sepal_length': 5.099999904632568, 'sepal_width': 3.799999952316284, 'petal_length': 1.899999976158142, 'petal_width': 0.4000000059604645}
# {'iris_type': '"Setosa"', 'sepal_length': 4.800000190734863, 'sepal_width': 3.0, 'petal_length': 1.399999976158142, 'petal_width': 0.30000001192092896}
# {'iris_type': '"Setosa"', 'sepal_length': 5.099999904632568, 'sepal_width': 3.799999952316284, 'petal_length': 1.600000023841858, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 4.599999904632568, 'sepal_width': 3.200000047683716, 'petal_length': 1.399999976158142, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 5.300000190734863, 'sepal_width': 3.700000047683716, 'petal_length': 1.5, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Setosa"', 'sepal_length': 5.0, 'sepal_width': 3.299999952316284, 'petal_length': 1.399999976158142, 'petal_width': 0.20000000298023224}
# {'iris_type': '"Versicolor"', 'sepal_length': 7.0, 'sepal_width': 3.200000047683716, 'petal_length': 4.699999809265137, 'petal_width': 1.399999976158142}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.400000095367432, 'sepal_width': 3.200000047683716, 'petal_length': 4.5, 'petal_width': 1.5}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.900000095367432, 'sepal_width': 3.0999999046325684, 'petal_length': 4.900000095367432, 'petal_width': 1.5}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.5, 'sepal_width': 2.299999952316284, 'petal_length': 4.0, 'petal_width': 1.2999999523162842}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.5, 'sepal_width': 2.799999952316284, 'petal_length': 4.599999904632568, 'petal_width': 1.5}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.699999809265137, 'sepal_width': 2.799999952316284, 'petal_length': 4.5, 'petal_width': 1.2999999523162842}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.300000190734863, 'sepal_width': 3.299999952316284, 'petal_length': 4.699999809265137, 'petal_width': 1.600000023841858}
# {'iris_type': '"Versicolor"', 'sepal_length': 4.900000095367432, 'sepal_width': 2.4000000953674316, 'petal_length': 3.299999952316284, 'petal_width': 1.0}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.599999904632568, 'sepal_width': 2.9000000953674316, 'petal_length': 4.599999904632568, 'petal_width': 1.2999999523162842}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.199999809265137, 'sepal_width': 2.700000047683716, 'petal_length': 3.9000000953674316, 'petal_width': 1.399999976158142}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.0, 'sepal_width': 2.0, 'petal_length': 3.5, 'petal_width': 1.0}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.900000095367432, 'sepal_width': 3.0, 'petal_length': 4.199999809265137, 'petal_width': 1.5}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.0, 'sepal_width': 2.200000047683716, 'petal_length': 4.0, 'petal_width': 1.0}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.099999904632568, 'sepal_width': 2.9000000953674316, 'petal_length': 4.699999809265137, 'petal_width': 1.399999976158142}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.599999904632568, 'sepal_width': 2.9000000953674316, 'petal_length': 3.5999999046325684, 'petal_width': 1.2999999523162842}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.699999809265137, 'sepal_width': 3.0999999046325684, 'petal_length': 4.400000095367432, 'petal_width': 1.399999976158142}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.599999904632568, 'sepal_width': 3.0, 'petal_length': 4.5, 'petal_width': 1.5}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.800000190734863, 'sepal_width': 2.700000047683716, 'petal_length': 4.099999904632568, 'petal_width': 1.0}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.199999809265137, 'sepal_width': 2.200000047683716, 'petal_length': 4.5, 'petal_width': 1.5}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.599999904632568, 'sepal_width': 2.5, 'petal_length': 3.9000000953674316, 'petal_width': 1.100000023841858}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.900000095367432, 'sepal_width': 3.200000047683716, 'petal_length': 4.800000190734863, 'petal_width': 1.7999999523162842}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.099999904632568, 'sepal_width': 2.799999952316284, 'petal_length': 4.0, 'petal_width': 1.2999999523162842}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.300000190734863, 'sepal_width': 2.5, 'petal_length': 4.900000095367432, 'petal_width': 1.5}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.099999904632568, 'sepal_width': 2.799999952316284, 'petal_length': 4.699999809265137, 'petal_width': 1.2000000476837158}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.400000095367432, 'sepal_width': 2.9000000953674316, 'petal_length': 4.300000190734863, 'petal_width': 1.2999999523162842}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.599999904632568, 'sepal_width': 3.0, 'petal_length': 4.400000095367432, 'petal_width': 1.399999976158142}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.800000190734863, 'sepal_width': 2.799999952316284, 'petal_length': 4.800000190734863, 'petal_width': 1.399999976158142}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.699999809265137, 'sepal_width': 3.0, 'petal_length': 5.0, 'petal_width': 1.7000000476837158}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.0, 'sepal_width': 2.9000000953674316, 'petal_length': 4.5, 'petal_width': 1.5}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.699999809265137, 'sepal_width': 2.5999999046325684, 'petal_length': 3.5, 'petal_width': 1.0}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.5, 'sepal_width': 2.4000000953674316, 'petal_length': 3.799999952316284, 'petal_width': 1.100000023841858}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.5, 'sepal_width': 2.4000000953674316, 'petal_length': 3.700000047683716, 'petal_width': 1.0}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.800000190734863, 'sepal_width': 2.700000047683716, 'petal_length': 3.9000000953674316, 'petal_width': 1.2000000476837158}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.0, 'sepal_width': 2.700000047683716, 'petal_length': 5.099999904632568, 'petal_width': 1.600000023841858}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.400000095367432, 'sepal_width': 3.0, 'petal_length': 4.5, 'petal_width': 1.5}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.0, 'sepal_width': 3.4000000953674316, 'petal_length': 4.5, 'petal_width': 1.600000023841858}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.699999809265137, 'sepal_width': 3.0999999046325684, 'petal_length': 4.699999809265137, 'petal_width': 1.5}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.300000190734863, 'sepal_width': 2.299999952316284, 'petal_length': 4.400000095367432, 'petal_width': 1.2999999523162842}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.599999904632568, 'sepal_width': 3.0, 'petal_length': 4.099999904632568, 'petal_width': 1.2999999523162842}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.5, 'sepal_width': 2.5, 'petal_length': 4.0, 'petal_width': 1.2999999523162842}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.5, 'sepal_width': 2.5999999046325684, 'petal_length': 4.400000095367432, 'petal_width': 1.2000000476837158}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.099999904632568, 'sepal_width': 3.0, 'petal_length': 4.599999904632568, 'petal_width': 1.399999976158142}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.800000190734863, 'sepal_width': 2.5999999046325684, 'petal_length': 4.0, 'petal_width': 1.2000000476837158}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.0, 'sepal_width': 2.299999952316284, 'petal_length': 3.299999952316284, 'petal_width': 1.0}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.599999904632568, 'sepal_width': 2.700000047683716, 'petal_length': 4.199999809265137, 'petal_width': 1.2999999523162842}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.699999809265137, 'sepal_width': 3.0, 'petal_length': 4.199999809265137, 'petal_width': 1.2000000476837158}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.699999809265137, 'sepal_width': 2.9000000953674316, 'petal_length': 4.199999809265137, 'petal_width': 1.2999999523162842}
# {'iris_type': '"Versicolor"', 'sepal_length': 6.199999809265137, 'sepal_width': 2.9000000953674316, 'petal_length': 4.300000190734863, 'petal_width': 1.2999999523162842}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.099999904632568, 'sepal_width': 2.5, 'petal_length': 3.0, 'petal_width': 1.100000023841858}
# {'iris_type': '"Versicolor"', 'sepal_length': 5.699999809265137, 'sepal_width': 2.799999952316284, 'petal_length': 4.099999904632568, 'petal_width': 1.2999999523162842}
# {'iris_type': '"Virginica"', 'sepal_length': 6.300000190734863, 'sepal_width': 3.299999952316284, 'petal_length': 6.0, 'petal_width': 2.5}
# {'iris_type': '"Virginica"', 'sepal_length': 5.800000190734863, 'sepal_width': 2.700000047683716, 'petal_length': 5.099999904632568, 'petal_width': 1.899999976158142}
# {'iris_type': '"Virginica"', 'sepal_length': 7.099999904632568, 'sepal_width': 3.0, 'petal_length': 5.900000095367432, 'petal_width': 2.0999999046325684}
# {'iris_type': '"Virginica"', 'sepal_length': 6.300000190734863, 'sepal_width': 2.9000000953674316, 'petal_length': 5.599999904632568, 'petal_width': 1.7999999523162842}
# {'iris_type': '"Virginica"', 'sepal_length': 6.5, 'sepal_width': 3.0, 'petal_length': 5.800000190734863, 'petal_width': 2.200000047683716}
# {'iris_type': '"Virginica"', 'sepal_length': 7.599999904632568, 'sepal_width': 3.0, 'petal_length': 6.599999904632568, 'petal_width': 2.0999999046325684}
# {'iris_type': '"Virginica"', 'sepal_length': 4.900000095367432, 'sepal_width': 2.5, 'petal_length': 4.5, 'petal_width': 1.7000000476837158}
# {'iris_type': '"Virginica"', 'sepal_length': 7.300000190734863, 'sepal_width': 2.9000000953674316, 'petal_length': 6.300000190734863, 'petal_width': 1.7999999523162842}
# {'iris_type': '"Virginica"', 'sepal_length': 6.699999809265137, 'sepal_width': 2.5, 'petal_length': 5.800000190734863, 'petal_width': 1.7999999523162842}
# {'iris_type': '"Virginica"', 'sepal_length': 7.199999809265137, 'sepal_width': 3.5999999046325684, 'petal_length': 6.099999904632568, 'petal_width': 2.5}
# {'iris_type': '"Virginica"', 'sepal_length': 6.5, 'sepal_width': 3.200000047683716, 'petal_length': 5.099999904632568, 'petal_width': 2.0}
# % t1 [0] at offset 300 with key None:
# % t1 [0] at offset 301 with key None:
# % t1 [0] at offset 302 with key None:
# % t1 [0] at offset 303 with key None:
# % t1 [0] at offset 304 with key None:
# % t1 [0] at offset 305 with key None:
# % t1 [0] at offset 306 with key None:
# % t1 [0] at offset 307 with key None:
# % t1 [0] at offset 308 with key None:
# % t1 [0] at offset 309 with key None:
# % t1 [0] at offset 310 with key None:
# % t1 [0] at offset 311 with key None:
# % t1 [0] at offset 312 with key None:
# % t1 [0] at offset 313 with key None:
# % t1 [0] at offset 314 with key None:
# % t1 [0] at offset 315 with key None:
# % t1 [0] at offset 316 with key None:
# % t1 [0] at offset 317 with key None:
# % t1 [0] at offset 318 with key None:
# % t1 [0] at offset 319 with key None:
# % t1 [0] at offset 320 with key None:
# % t1 [0] at offset 321 with key None:
# % t1 [0] at offset 322 with key None:
# % t1 [0] at offset 323 with key None:
# % t1 [0] at offset 324 with key None:
# % t1 [0] at offset 325 with key None:
# % t1 [0] at offset 326 with key None:
# % t1 [0] at offset 327 with key None:
# % t1 [0] at offset 328 with key None:
# % t1 [0] at offset 329 with key None:
# % t1 [0] at offset 330 with key None:
# % t1 [0] at offset 331 with key None:
# % t1 [0] at offset 332 with key None:
# % t1 [0] at offset 333 with key None:
# % t1 [0] at offset 334 with key None:
# % t1 [0] at offset 335 with key None:
# % t1 [0] at offset 336 with key None:
# % t1 [0] at offset 337 with key None:
# % t1 [0] at offset 338 with key None:
# % t1 [0] at offset 339 with key None:
# % t1 [0] at offset 340 with key None:
# % t1 [0] at offset 341 with key None:
# % t1 [0] at offset 342 with key None:
# % t1 [0] at offset 343 with key None:
# % t1 [0] at offset 344 with key None:
# % t1 [0] at offset 345 with key None:
# % t1 [0] at offset 346 with key None:
# % t1 [0] at offset 347 with key None:
# % t1 [0] at offset 348 with key None:
# % t1 [0] at offset 349 with key None:
# % t1 [0] at offset 350 with key None:
# % t1 [0] at offset 351 with key None:
# % t1 [0] at offset 352 with key None:
# % t1 [0] at offset 353 with key None:
# % t1 [0] at offset 354 with key None:
# % t1 [0] at offset 355 with key None:
# % t1 [0] at offset 356 with key None:
# % t1 [0] at offset 357 with key None:
# % t1 [0] at offset 358 with key None:
# % t1 [0] at offset 359 with key None:
# % t1 [0] at offset 360 with key None:
# % t1 [0] at offset 361 with key None:
# % t1 [0] at offset 362 with key None:
# % t1 [0] at offset 363 with key None:
# % t1 [0] at offset 364 with key None:
# % t1 [0] at offset 365 with key None:
# % t1 [0] at offset 366 with key None:
# % t1 [0] at offset 367 with key None:
# % t1 [0] at offset 368 with key None:
# % t1 [0] at offset 369 with key None:
# % t1 [0] at offset 370 with key None:
# % t1 [0] at offset 371 with key None:
# % t1 [0] at offset 372 with key None:
# % t1 [0] at offset 373 with key None:
# % t1 [0] at offset 374 with key None:
# % t1 [0] at offset 375 with key None:
# % t1 [0] at offset 376 with key None:
# % t1 [0] at offset 377 with key None:
# % t1 [0] at offset 378 with key None:
# % t1 [0] at offset 379 with key None:
# % t1 [0] at offset 380 with key None:
# % t1 [0] at offset 381 with key None:
# % t1 [0] at offset 382 with key None:
# % t1 [0] at offset 383 with key None:
# % t1 [0] at offset 384 with key None:
# % t1 [0] at offset 385 with key None:
# % t1 [0] at offset 386 with key None:
# % t1 [0] at offset 387 with key None:
# % t1 [0] at offset 388 with key None:
# % t1 [0] at offset 389 with key None:
# % t1 [0] at offset 390 with key None:
# % t1 [0] at offset 391 with key None:
# % t1 [0] at offset 392 with key None:
# % t1 [0] at offset 393 with key None:
# % t1 [0] at offset 394 with key None:
# % t1 [0] at offset 395 with key None:
# % t1 [0] at offset 396 with key None:
# % t1 [0] at offset 397 with key None:
# % t1 [0] at offset 398 with key None:
# % t1 [0] at offset 399 with key None:
# % t1 [0] at offset 400 with key None:
# % t1 [0] at offset 401 with key None:
# % t1 [0] at offset 402 with key None:
# % t1 [0] at offset 403 with key None:
# % t1 [0] at offset 404 with key None:
# % t1 [0] at offset 405 with key None:
# % t1 [0] at offset 406 with key None:
# % t1 [0] at offset 407 with key None:
# % t1 [0] at offset 408 with key None:
# % t1 [0] at offset 409 with key None:
# % t1 [0] at offset 410 with key None:
# {'iris_type': '"Virginica"', 'sepal_length': 6.400000095367432, 'sepal_width': 2.700000047683716, 'petal_length': 5.300000190734863, 'petal_width': 1.899999976158142}
# {'iris_type': '"Virginica"', 'sepal_length': 6.800000190734863, 'sepal_width': 3.0, 'petal_length': 5.5, 'petal_width': 2.0999999046325684}
# {'iris_type': '"Virginica"', 'sepal_length': 5.699999809265137, 'sepal_width': 2.5, 'petal_length': 5.0, 'petal_width': 2.0}
# {'iris_type': '"Virginica"', 'sepal_length': 5.800000190734863, 'sepal_width': 2.799999952316284, 'petal_length': 5.099999904632568, 'petal_width': 2.4000000953674316}
# {'iris_type': '"Virginica"', 'sepal_length': 6.400000095367432, 'sepal_width': 3.200000047683716, 'petal_length': 5.300000190734863, 'petal_width': 2.299999952316284}
# {'iris_type': '"Virginica"', 'sepal_length': 6.5, 'sepal_width': 3.0, 'petal_length': 5.5, 'petal_width': 1.7999999523162842}
# {'iris_type': '"Virginica"', 'sepal_length': 7.699999809265137, 'sepal_width': 3.799999952316284, 'petal_length': 6.699999809265137, 'petal_width': 2.200000047683716}
# {'iris_type': '"Virginica"', 'sepal_length': 7.699999809265137, 'sepal_width': 2.5999999046325684, 'petal_length': 6.900000095367432, 'petal_width': 2.299999952316284}
# {'iris_type': '"Virginica"', 'sepal_length': 6.0, 'sepal_width': 2.200000047683716, 'petal_length': 5.0, 'petal_width': 1.5}
# {'iris_type': '"Virginica"', 'sepal_length': 6.900000095367432, 'sepal_width': 3.200000047683716, 'petal_length': 5.699999809265137, 'petal_width': 2.299999952316284}
# {'iris_type': '"Virginica"', 'sepal_length': 5.599999904632568, 'sepal_width': 2.799999952316284, 'petal_length': 4.900000095367432, 'petal_width': 2.0}
# {'iris_type': '"Virginica"', 'sepal_length': 7.699999809265137, 'sepal_width': 2.799999952316284, 'petal_length': 6.699999809265137, 'petal_width': 2.0}
# {'iris_type': '"Virginica"', 'sepal_length': 6.300000190734863, 'sepal_width': 2.700000047683716, 'petal_length': 4.900000095367432, 'petal_width': 1.7999999523162842}
# {'iris_type': '"Virginica"', 'sepal_length': 6.699999809265137, 'sepal_width': 3.299999952316284, 'petal_length': 5.699999809265137, 'petal_width': 2.0999999046325684}
# {'iris_type': '"Virginica"', 'sepal_length': 7.199999809265137, 'sepal_width': 3.200000047683716, 'petal_length': 6.0, 'petal_width': 1.7999999523162842}
# {'iris_type': '"Virginica"', 'sepal_length': 6.199999809265137, 'sepal_width': 2.799999952316284, 'petal_length': 4.800000190734863, 'petal_width': 1.7999999523162842}
# {'iris_type': '"Virginica"', 'sepal_length': 6.099999904632568, 'sepal_width': 3.0, 'petal_length': 4.900000095367432, 'petal_width': 1.7999999523162842}
# {'iris_type': '"Virginica"', 'sepal_length': 6.400000095367432, 'sepal_width': 2.799999952316284, 'petal_length': 5.599999904632568, 'petal_width': 2.0999999046325684}
# {'iris_type': '"Virginica"', 'sepal_length': 7.199999809265137, 'sepal_width': 3.0, 'petal_length': 5.800000190734863, 'petal_width': 1.600000023841858}
# {'iris_type': '"Virginica"', 'sepal_length': 7.400000095367432, 'sepal_width': 2.799999952316284, 'petal_length': 6.099999904632568, 'petal_width': 1.899999976158142}
# {'iris_type': '"Virginica"', 'sepal_length': 7.900000095367432, 'sepal_width': 3.799999952316284, 'petal_length': 6.400000095367432, 'petal_width': 2.0}
# {'iris_type': '"Virginica"', 'sepal_length': 6.400000095367432, 'sepal_width': 2.799999952316284, 'petal_length': 5.599999904632568, 'petal_width': 2.200000047683716}
# {'iris_type': '"Virginica"', 'sepal_length': 6.300000190734863, 'sepal_width': 2.799999952316284, 'petal_length': 5.099999904632568, 'petal_width': 1.5}
# {'iris_type': '"Virginica"', 'sepal_length': 6.099999904632568, 'sepal_width': 2.5999999046325684, 'petal_length': 5.599999904632568, 'petal_width': 1.399999976158142}
# {'iris_type': '"Virginica"', 'sepal_length': 7.699999809265137, 'sepal_width': 3.0, 'petal_length': 6.099999904632568, 'petal_width': 2.299999952316284}
# {'iris_type': '"Virginica"', 'sepal_length': 6.300000190734863, 'sepal_width': 3.4000000953674316, 'petal_length': 5.599999904632568, 'petal_width': 2.4000000953674316}
# {'iris_type': '"Virginica"', 'sepal_length': 6.400000095367432, 'sepal_width': 3.0999999046325684, 'petal_length': 5.5, 'petal_width': 1.7999999523162842}
# {'iris_type': '"Virginica"', 'sepal_length': 6.0, 'sepal_width': 3.0, 'petal_length': 4.800000190734863, 'petal_width': 1.7999999523162842}
# {'iris_type': '"Virginica"', 'sepal_length': 6.900000095367432, 'sepal_width': 3.0999999046325684, 'petal_length': 5.400000095367432, 'petal_width': 2.0999999046325684}
# {'iris_type': '"Virginica"', 'sepal_length': 6.699999809265137, 'sepal_width': 3.0999999046325684, 'petal_length': 5.599999904632568, 'petal_width': 2.4000000953674316}
# {'iris_type': '"Virginica"', 'sepal_length': 6.900000095367432, 'sepal_width': 3.0999999046325684, 'petal_length': 5.099999904632568, 'petal_width': 2.299999952316284}
# {'iris_type': '"Virginica"', 'sepal_length': 5.800000190734863, 'sepal_width': 2.700000047683716, 'petal_length': 5.099999904632568, 'petal_width': 1.899999976158142}
# {'iris_type': '"Virginica"', 'sepal_length': 6.800000190734863, 'sepal_width': 3.200000047683716, 'petal_length': 5.900000095367432, 'petal_width': 2.299999952316284}
# {'iris_type': '"Virginica"', 'sepal_length': 6.699999809265137, 'sepal_width': 3.299999952316284, 'petal_length': 5.699999809265137, 'petal_width': 2.5}
# {'iris_type': '"Virginica"', 'sepal_length': 6.699999809265137, 'sepal_width': 3.0, 'petal_length': 5.199999809265137, 'petal_width': 2.299999952316284}
# {'iris_type': '"Virginica"', 'sepal_length': 6.300000190734863, 'sepal_width': 2.5, 'petal_length': 5.0, 'petal_width': 1.899999976158142}
# {'iris_type': '"Virginica"', 'sepal_length': 6.5, 'sepal_width': 3.0, 'petal_length': 5.199999809265137, 'petal_width': 2.0}
# {'iris_type': '"Virginica"', 'sepal_length': 6.199999809265137, 'sepal_width': 3.4000000953674316, 'petal_length': 5.400000095367432, 'petal_width': 2.299999952316284}
# {'iris_type': '"Virginica"', 'sepal_length': 5.900000095367432, 'sepal_width': 3.0, 'petal_length': 5.099999904632568, 'petal_width': 1.7999999523162842}
# % t1 [0] at offset 411 with key None:
# % t1 [0] at offset 412 with key None:
# % t1 [0] at offset 413 with key None:
# % t1 [0] at offset 414 with key None:
# % t1 [0] at offset 415 with key None:
# % t1 [0] at offset 416 with key None:
# % t1 [0] at offset 417 with key None:
# % t1 [0] at offset 418 with key None:
# % t1 [0] at offset 419 with key None:
# % t1 [0] at offset 420 with key None:
# % t1 [0] at offset 421 with key None:
# % t1 [0] at offset 422 with key None:
# % t1 [0] at offset 423 with key None:
# % t1 [0] at offset 424 with key None:
# % t1 [0] at offset 425 with key None:
# % t1 [0] at offset 426 with key None:
# % t1 [0] at offset 427 with key None:
# % t1 [0] at offset 428 with key None:
# % t1 [0] at offset 429 with key None:
# % t1 [0] at offset 430 with key None:
# % t1 [0] at offset 431 with key None:
# % t1 [0] at offset 432 with key None:
# % t1 [0] at offset 433 with key None:
# % t1 [0] at offset 434 with key None:
# % t1 [0] at offset 435 with key None:
# % t1 [0] at offset 436 with key None:
# % t1 [0] at offset 437 with key None:
# % t1 [0] at offset 438 with key None:
# % t1 [0] at offset 439 with key None:
# % t1 [0] at offset 440 with key None:
# % t1 [0] at offset 441 with key None:
# % t1 [0] at offset 442 with key None:
# % t1 [0] at offset 443 with key None:
# % t1 [0] at offset 444 with key None:
# % t1 [0] at offset 445 with key None:
# % t1 [0] at offset 446 with key None:
# % t1 [0] at offset 447 with key None:
# % t1 [0] at offset 448 with key None:
# % t1 [0] at offset 449 with key None:
